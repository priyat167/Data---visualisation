# %% [markdown]
# <a href="https://colab.research.google.com/github/priyat167/Data---visualisation/blob/main/Data_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
color = sns.color_palette()
import sklearn.metrics as metrics
from warnings import warn

# %%
data = pd.read_csv("/content/gdrive/MyDrive/csv_test.csv")
data.head()
# Out:
#          Date Close/Last   Volume      Open        High       Low
# 0  02/18/2022   $3052.03  3180205  $3109.99    $3109.99  $3017.86
# 1  02/17/2022   $3093.05  3201625  $3162.92   $3206.975     $3090
# 2  02/16/2022   $3162.01  2635214  $3115.81    $3176.68  $3094.69
# 3  02/15/2022   $3130.21  2848533  $3152.11    $3160.14  $3092.75
# 4  02/14/2022   $3103.34  4161535  $3035.02  $3168.9663     $3033

# %%
data.describe()
# Out:
#              Volume
# count  2.000000e+01
# mean   4.778961e+06
# std    2.706971e+06
# min    2.635214e+06
# 25%    3.360461e+06
# 50%    3.865406e+06
# 75%    4.600946e+06
# max    1.267279e+07

# %%
data.tail()
# Out:
#           Date Close/Last   Volume      Open       High        Low
# 15  01/28/2022   $2879.56  3719599  $2817.21   $2879.96  $2758.585
# 16  01/27/2022   $2792.75  3875790     $2816   $2884.87      $2787
# 17  01/26/2022   $2777.45  4780085     $2895  $2903.695   $2746.37
# 18  01/25/2022   $2799.72  4541233  $2844.85      $2872    $2762.9
# 19  01/24/2022   $2890.88  7802237     $2780    $2898.9   $2707.04

# %%
data.dtypes
# Out:
# Date          object
# Close/Last    object
# Volume         int64
# Open          object
# High          object
# Low           object
# dtype: object

# %%
data = data.replace({'\$':''}, regex = True) 
data.head()
# Out:
#          Date Close/Last   Volume     Open       High      Low
# 0  02/18/2022    3052.03  3180205  3109.99    3109.99  3017.86
# 1  02/17/2022    3093.05  3201625  3162.92   3206.975     3090
# 2  02/16/2022    3162.01  2635214  3115.81    3176.68  3094.69
# 3  02/15/2022    3130.21  2848533  3152.11    3160.14  3092.75
# 4  02/14/2022    3103.34  4161535  3035.02  3168.9663     3033

# %%
df = data
df.columns = ['Date', 'Close', 'Volume', 'Open', 'High', 'Low'] 
df = df.astype({"Close": float, "Volume": int, "Open": float, "High": float, "Low": float})
df.dtypes
# Out:
# Date       object
# Close     float64
# Volume      int64
# Open      float64
# High      float64
# Low       float64
# dtype: object

# %%
data.describe(include = 'all')
# Out:
#               Date    Close        Volume  Open     High      Low
# count           20       20  2.000000e+01    20       20       20
# unique          20       20           NaN    19       20       20
# top     02/18/2022  3052.03           NaN  2895  3109.99  3017.86
# freq             1        1           NaN     2        1        1
# mean           NaN      NaN  4.778961e+06   NaN      NaN      NaN
# std            NaN      NaN  2.706971e+06   NaN      NaN      NaN
# min            NaN      NaN  2.635214e+06   NaN      NaN      NaN
# 25%            NaN      NaN  3.360461e+06   NaN      NaN      NaN
# 50%            NaN      NaN  3.865406e+06   NaN      NaN      NaN
# 75%            NaN      NaN  4.600946e+06   NaN      NaN      NaN
# max            NaN      NaN  1.267279e+07   NaN      NaN      NaN

# %%
df.describe(include = "float")
# Out:
#              Close         Open         High          Low
# count    20.000000    20.000000    20.000000    20.000000
# mean   3024.750000  3028.218425  3083.734065  2967.776830
# std     153.905292   152.224862   147.530342   160.439323
# min    2776.910000  2780.000000  2872.000000  2707.040000
# 25%    2888.050000  2882.462500  2902.496250  2781.915000
# 50%    3058.950000  3105.499250  3135.065000  3015.010000
# 75%    3154.270000  3154.755000  3208.813750  3093.235000
# max    3228.270000  3257.470000  3276.690000  3205.000000

# %%
df.describe(include = "object")
# Out:
#               Date
# count           20
# unique          20
# top     02/18/2022
# freq             1

# %%
df.describe(exclude = "int")
# Out:
#               Date        Close         Open         High          Low
# count           20    20.000000    20.000000    20.000000    20.000000
# unique          20          NaN          NaN          NaN          NaN
# top     02/18/2022          NaN          NaN          NaN          NaN
# freq             1          NaN          NaN          NaN          NaN
# mean           NaN  3024.750000  3028.218425  3083.734065  2967.776830
# std            NaN   153.905292   152.224862   147.530342   160.439323
# min            NaN  2776.910000  2780.000000  2872.000000  2707.040000
# 25%            NaN  2888.050000  2882.462500  2902.496250  2781.915000
# 50%            NaN  3058.950000  3105.499250  3135.065000  3015.010000
# 75%            NaN  3154.270000  3154.755000  3208.813750  3093.235000
# max            NaN  3228.270000  3257.470000  3276.690000  3205.000000

# %%
df.describe(percentiles = [0.1, 0.5, 0.9])
# Out:
#              Close        Volume         Open         High          Low
# count    20.000000  2.000000e+01    20.000000    20.000000    20.000000
# mean   3024.750000  4.778961e+06  3028.218425  3083.734065  2967.776830
# std     153.905292  2.706971e+06   152.224862   147.530342   160.439323
# min    2776.910000  2.635214e+06  2780.000000  2872.000000  2707.040000
# 10%    2791.220000  2.949746e+06  2817.089000  2884.379000  2757.363500
# 50%    3058.950000  3.865406e+06  3105.499250  3135.065000  3015.010000
# 90%    3184.442000  8.149670e+06  3167.340000  3237.646500  3146.000000
# max    3228.270000  1.267279e+07  3257.470000  3276.690000  3205.000000

# %%
# Closing price more than 3000
mask_closeprice = df.Close > 3000 
high_price = df.loc[mask_closeprice] 
high_price.head()
# Out:
#          Date    Close   Volume     Open       High      Low
# 0  02/18/2022  3052.03  3180205  3109.99  3109.9900  3017.86
# 1  02/17/2022  3093.05  3201625  3162.92  3206.9750  3090.00
# 2  02/16/2022  3162.01  2635214  3115.81  3176.6800  3094.69
# 3  02/15/2022  3130.21  2848533  3152.11  3160.1400  3092.75
# 4  02/14/2022  3103.34  4161535  3035.02  3168.9663  3033.00

# %%
# Closing price more than 3000 and traded volume more than 5

mask_closeprice = df.Close > 3000 
mask_volume = df.Volume > 5000000
millionhigh_price_volume = df.loc[mask_closeprice & mask_volume]
 
millionhigh_price_volume
# Out:
#           Date    Close    Volume     Open      High      Low
# 9   02/07/2022  3158.71   5131219  3170.40  3253.815  3145.00
# 10  02/04/2022  3152.79  12672790  3112.13  3224.000  3012.16

# %%
df.plot(x='Date', y='Close')

# %%
df.plot(x='Date', y='Close', rot=90)

# %%
df.plot(x='Date', y='Close', rot=90, title="AMZN Stock Price")

# %%
df.plot(x='Date', y='Close', kind='scatter', rot=90, title="AMZN Stock Price")

# %%
df.plot(x='Date', y='Volume', kind='hist', rot=90, title="AMZN Stock Price")
